# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianQian1999/DD2360HT22/blob/main/hw_3/ex_4/lab3_ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CPU version:

# %%
# !make
# Out:
# [ -d . ] || mkdir .
# nvcc -std=c++11 -O3 -g -Xcompiler -Wall Grid.cpp -c -o Grid.o
# [ -d . ] || mkdir .
# nvcc -std=c++11 -O3 -g -Xcompiler -Wall TransArraySpace3D.cpp -c -o TransArraySpace3D.o
# nvcc -std=c++11 -O3 -g -Xcompiler -Wall --compiler-bindir=g++ Particles.cu -c -o Particles.o
# Particles.cu: In function ‘int mover_PC(particles*, EMfield*, grid*, parameters*)’:
# Particles.cu:162:38: warning: ‘wptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->z[i] = zptilde + wptilde*dt_sub_cycling;
#                              ~~~~~~~~~^~~~~~~~~~~~~~~~~
# Particles.cu:158:26: warning: ‘vptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->v[i]= 2.0*vptilde - part->v[i];
#                    ~~~~~~~^~~~~~~~~~
# Particles.cu:157:26: warning: ‘uptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->u[i]= 2.0*uptilde - part->u[i];
# ...

# %%
# !./sputniPIC.out GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ** rho species 1 = 1 CURRENT SHEET
# ...

# %% [markdown]
# GPU version:

# %%
# !make
# !./sputniPIC.out GEM_2D.inp
# Out:
# make: Nothing to be done for 'all'.
#
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ...
